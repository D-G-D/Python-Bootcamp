# %% [markdown]
# # Orders to suppliers (Data Types)

# %% [markdown]
# ## Data types

# %%
type(2384400)
# Out:
# int

# %%
type(2384400 / 10000)
# Out:
# float

# %%
type(M04JP)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 type(M04JP)
#
# NameError: name 'M04JP' is not defined

# %% [markdown]
# M04JP is a non-defined variable.

# %%
type('M04JP')
# Out:
# str

# %%
avg_cost_unit = 2384400 / 10000
avg_cost_unit
# Out:
# 238.44

# %%
avg_cost_unit < 300
# Out:
# True

# %%
type(avg_cost_unit < 200)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
avg_cost_unit
# Out:
# 238.44

# %% [markdown]
# We can also convert the type if needed:

# %%
int(avg_cost_unit)
# Out:
# 238

# %%
str(avg_cost_unit)
# Out:
# '238.44'

# %%
float(int(avg_cost_unit))
# Out:
# 238.0

# %%
label = 'm04jp5000'
int(label[5:])
# Out:
# 5000
